# %%
# automatically reload the imports
# %load_ext autoreload
# %autoreload 2

from scraper import parse_post_ids_from_html_file

for i in [7]:
    post_ids = parse_post_ids_from_html_file(f"inputs/anthropic/{i}.html")
    print(i, len(post_ids), post_ids)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 7 21 ['1162594', '1162478', '1162131', '1162037', '1161877', '1161686', '1161406', '1161165', '1161097', '1160706', '7478554', '1160525', '1160362', '1160344', '1160254', '1159633', '1159459', '1159248', '1158823', '1158568', '1158532']

# %%
len(post_ids)
# Out:
# 20

# %%
# Out:
# 13.333333333333334
